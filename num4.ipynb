# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyasoni1409-alt/python/blob/main/num4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.
# Create two NumPy arrays: one representing the number of likes on your last 7 Instagram posts, and another for the number of comments. Use arithmetic operators to calculate the average engagement (likes + comments) per post and print the result.
# # New Section

# %%
import numpy as np

likes = np.array([120, 250, 340, 180, 500, 420, 300])

comments = np.array([10, 25, 30, 15, 45, 35, 20])

engagement = likes + comments

average_engagement = engagement.mean()

print("Likes:", likes)
print("Comments:", comments)
print("Engagement per post:", engagement)
print("Average engagement:", average_engagement)
# Out:
# Likes: [120 250 340 180 500 420 300]
# Comments: [10 25 30 15 45 35 20]
# Engagement per post: [130 275 370 195 545 455 320]
# Average engagement: 327.14285714285717

# %% [markdown]
# 2.
# Given two NumPy arrays: one with the prices of 5 food items on Zomato and another with the corresponding discounts in rupees, use element-wise subtraction to get the final price for each item and display the array.

# %%
import numpy as np

# Original prices of 5 Zomato food items
prices = np.array([250, 180, 300, 150, 220])

# Discounts in rupees
discounts = np.array([20, 30, 50, 10, 40])

# Calculate final price
final_prices = prices - discounts

print("Original prices:", prices)
print("Discounts:", discounts)
print("Final prices:", final_prices)
# Out:
# Original prices: [250 180 300 150 220]
# Discounts: [20 30 50 10 40]
# Final prices: [230 150 250 140 180]

# %% [markdown]
# 3.
# Suppose you have a NumPy array of IPL team scores for 5 matches. Use comparison operators to create a boolean array indicating which matches had scores greater than 180, then print the boolean array.<br><br><em><strong>Hint:</strong> Use the '>' operator directly on the array.</em>

# %%
import numpy as np

scores = np.array([175, 195, 160, 210, 185])

result = scores > 180

print("IPL scores:", scores)
print("Scores greater than 180:", result)
# Out:
# IPL scores: [175 195 160 210 185]
# Scores greater than 180: [False  True False  True  True]

# %% [markdown]
# 4.
# Create two NumPy arrays: one showing whether a user paid via Paytm (1 for paid, 0 for not) and another for PhonePe for 6 transactions. Use np.logical_or() to find out which transactions were paid by either app and print the result.

# %%
import numpy as np

paytm = np.array([1, 0, 1, 0, 0, 1])

phonepe = np.array([0, 1, 1, 0, 1, 0])

result = np.logical_or(paytm, phonepe)

print("Paytm:", paytm)
print("PhonePe:", phonepe)
print("Paid by either app:", result)
# Out:
# Paytm: [1 0 1 0 0 1]
# PhonePe: [0 1 1 0 1 0]
# Paid by either app: [ True  True  True False  True  True]

# %% [markdown]
# 5.
# Given a NumPy array of the number of steps you walked each day for a week, use broadcasting to add a bonus of 500 steps to each day's count, then calculate and print the total steps for the week using an aggregate operation.

# %%
import numpy as np

steps = np.array([5000, 6500, 7000, 4500, 8000, 6000, 7500])

bonus_steps = 500
updated_steps = steps + bonus_steps

total_steps = updated_steps.sum()

print("Original steps:", steps)
print("Steps after 500 bonus:", updated_steps)
print("Total steps for the week:", total_steps)
# Out:
# Original steps: [5000 6500 7000 4500 8000 6000 7500]
# Steps after 500 bonus: [5500 7000 7500 5000 8500 6500 8000]
# Total steps for the week: 48000
