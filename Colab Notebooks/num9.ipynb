# %% [markdown]
# 1.
# Create a NumPy array named prices with these values: [299, 499, 799, 0, 1599, -1, 899]. Print the array and its data type.

# %%
import numpy as np

prices = np.array([299, 499, 799, 0, 1599, -1, 899])

print("Prices:", prices)
print("Data type:", prices.dtype)
# Out:
# Prices: [ 299  499  799    0 1599   -1  899]
# Data type: int64

# %% [markdown]
# 2.
# Some entries in the prices array are invalid (0 or negative). Replace all values less than or equal to zero with the average of the remaining positive prices.<br><br><em><strong>Hint:</strong> Use boolean indexing and the mean() function.</em>

# %%
import numpy as np

prices = np.array([299, 499, 799, 0, 1599, -1, 899])

positive_prices = prices[prices > 0]

average_price = positive_prices.mean()

cleaned_prices = np.where(prices <= 0, average_price, prices)

print("Average price:", average_price)
print("Cleaned prices:", cleaned_prices)
# Out:
# Average price: 819.0
# Cleaned prices: [ 299.  499.  799.  819. 1599.  819.  899.]

# %% [markdown]
# 3.
# Suppose you have a NumPy array quantities = [2, 1, 3, 4, 2, 1, 5]. Calculate the total bill for each item by multiplying the cleaned prices array with quantities, and print the resulting array.

# %%
import numpy as np

prices = np.array([299, 499, 799, 0, 1599, -1, 899])

positive_prices = prices[prices > 0]
average_price = positive_prices.mean()

cleaned_prices = np.where(prices <= 0, average_price, prices)

quantities = np.array([2, 1, 3, 4, 2, 1, 5])

item_bills = cleaned_prices * quantities

print("Cleaned prices:", cleaned_prices)
print("Quantities:", quantities)
print("Total bill for each item:", item_bills)
# Out:
# Cleaned prices: [ 299.  499.  799.  819. 1599.  819.  899.]
# Quantities: [2 1 3 4 2 1 5]
# Total bill for each item: [ 598.  499. 2397. 3276. 3198.  819. 4495.]

# %% [markdown]
# 4.
# Generate and print a summary report: show the minimum, maximum, average, and total of the cleaned prices array, and also the total bill for all items combined.<br><br><em><strong>Hint:</strong> Use NumPy functions like min(), max(), mean(), and sum().</em>

# %%
import numpy as np

prices = np.array([299, 499, 799, 0, 1599, -1, 899])

positive_prices = prices[prices > 0]
average_price = positive_prices.mean()

cleaned_prices = np.where(prices <= 0, average_price, prices)

quantities = np.array([2, 1, 3, 4, 2, 1, 5])

item_bills = cleaned_prices * quantities

print("----- SUMMARY REPORT -----")
print("Minimum price:", cleaned_prices.min())
print("Maximum price:", cleaned_prices.max())
print("Average price:", cleaned_prices.mean())
print("Total of prices:", cleaned_prices.sum())
print("Total bill:", item_bills.sum())
# Out:
# ----- SUMMARY REPORT -----
# Minimum price: 299.0
# Maximum price: 1599.0
# Average price: 819.0
# Total of prices: 5733.0
# Total bill: 15282.0

# %% [markdown]
# 5.
# Use ChatGPT or Copilot to suggest a NumPy function or method that can help you find out how many unique price values are present in your cleaned prices array. Try the suggested method and print the result.

# %%
import numpy as np

prices = np.array([299, 499, 799, 0, 1599, -1, 899])

positive_prices = prices[prices > 0]
average_price = positive_prices.mean()

cleaned_prices = np.where(prices <= 0, average_price, prices)

unique_prices = np.unique(cleaned_prices)

print("Cleaned prices:", cleaned_prices)
print("Unique prices:", unique_prices)
print("Number of unique prices:", len(unique_prices))
# Out:
# Cleaned prices: [ 299.  499.  799.  819. 1599.  819.  899.]
# Unique prices: [ 299.  499.  799.  819.  899. 1599.]
# Number of unique prices: 6
